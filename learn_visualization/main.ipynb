# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_val = np.random.rand(6)
y_val = np.random.rand(6)

plt.plot(x_val, y_val)
plt.show()

# %%
# https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166

# %%
data = pd.read_csv("./final_vg.csv")

data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
# Categorical columns
unique_categories = data["Genre"].unique()
unique_categories
# Out:
# <StringArray>
# [     'Shooter',     'Platform',       'Action', 'Role-Playing',
#        'Racing',         'Misc',    'Adventure',       'Sports',
#        'Puzzle',   'Simulation',     'Strategy',     'Fighting']
# Length: 12, dtype: str

# %%
category_counts = data["Genre"].value_counts()
category_counts
# Out:
# Genre
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %%
# Top 5 genres from the data
category_counts[0:5]
# Out:
# Genre
# Action          3316
# Sports          2400
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: count, dtype: int64

# %% [markdown]
# ### Bar charts are used to represent the counts

# %%
# Bar charts
x_bar = category_counts.index
x_bar
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter', 'Adventure',
#        'Racing', 'Platform', 'Simulation', 'Fighting', 'Strategy', 'Puzzle'],
#       dtype='str', name='Genre')

# %%
y_bar = category_counts.values
y_bar
# Out:
# array([3316, 2400, 1739, 1488, 1310, 1286, 1249,  886,  867,  848,  681,
#         582])

# %%
plt.bar(x_bar, y_bar)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.figure(figsize=(12, 8))
plt.bar(x_bar, y_bar)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.figure(figsize=(12, 8))
plt.xticks(rotation=30, fontsize=12)
plt.bar(x_bar, y_bar, width=0.4, color="#ce3300")
plt.xlabel("Video Game Genre", fontsize=14)
plt.ylabel("Number of games", fontsize=14)
plt.title("Genre analysis", fontsize=24)

plt.show()

# %%
# Using seaborn
sns.countplot(x="Genre",
              data=data,
              order=data["Genre"].value_counts().index,
              color="#1db868",
              width=0.6,
              )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Pie charts are used to visualize proportions

# %%
sales_data = data[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]]
regional_sales = sales_data.T.sum(axis="columns")
pd.DataFrame(regional_sales)
# Out:
#                         0
# NA_Sales     45831.525845
# EU_Sales     33251.970702
# JP_Sales     41624.625635
# Other_Sales  19180.256828

# %%
total_sales = sales_data.sum().sum()
print(total_sales)
# Out:
# 139888.3790100206

# %%
plt.pie(x=regional_sales,
        labels=regional_sales.index,
        startangle=90,
        explode=[0.1] + [0] * (len(regional_sales) - 1),
        autopct="%1.1f%%",
        )
plt.title("Total Sales Across Regions")
plt.show()

# %%
# Histogram
data.head()
# Out:
#     Rank                               Name Platform    Year         Genre  \
# 0   2061                               1942      NES  1985.0       Shooter
# 1   9137       ¡Shin Chan Flipa en colores!       DS  2007.0      Platform
# 2  14279  .hack: Sekai no Mukou ni + Versus      PS3  2012.0        Action
# 3   8359         .hack//G.U. Vol.1//Rebirth      PS2  2006.0  Role-Playing
# 4   7109       .hack//G.U. Vol.2//Reminisce      PS2  2006.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0              Capcom  4.569217  3.033887  3.439352     1.991671     12.802935
# 1           505 Games  2.076955  1.493442  3.033887     0.394830      7.034163
# 2  Namco Bandai Games  1.145709  1.762339  1.493442     0.408693      4.982552
# 3  Namco Bandai Games  2.031986  1.389856  3.228043     0.394830      7.226880
# 4  Namco Bandai Games  2.792725  2.592054  1.440483     1.493442      8.363113

# %%
plt.hist(data["Year"].sort_values(ascending=False), color="red", alpha=0.6)
plt.hist(data["Year"], color="blue", alpha=0.6)
plt.title("Year and Count Plot")
plt.show()

# %%
from sklearn.datasets import load_digits

X, y = load_digits(return_X_y=True)

X, y
# Out:
# (array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]], shape=(1797, 64)),
#  array([0, 1, 2, ..., 8, 9, 8], shape=(1797,)))

# %%
from sklearn.neighbors import KNeighborsRegressor

mod = KNeighborsRegressor()

# %%
mod.fit(X, y)
# Out:
# KNeighborsRegressor()

# %%
predictions = mod.predict(X)
predictions
# Out:
# array([0., 1., 2., ..., 8., 9., 8.], shape=(1797,))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(predictions, y)
plt.show()
