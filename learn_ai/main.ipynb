# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_val = np.random.rand(6)
y_val = np.random.rand(6)

plt.plot(x_val, y_val)
plt.show()

https://d2beiqkhq929f0.cloudfront.net/public_assets/000/021/299/

# %%
import pandas as pd

data = {
    "Name": ["Mohit", "Ayush", "Vikash"],
    "Names": ["Mohit", "Ayush", "Vikash"],
}

df = pd.DataFrame(data)


# https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/021/299/original/final_vg1_-_final_vg_%281%29.csv?1670840166
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
