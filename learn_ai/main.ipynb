# %% [markdown]
# # Let's learn AI-ML for Data Science
#
# - Point 1
# - point 2
#
#
# ## Subheading
#
# <center>Hello, world!</center>

# %%
import numpy as np


num = np.random.randn(10)

num
# Out:
# array([ 0.59521676,  0.72062339, -0.61629558, -0.35510338,  1.75589866,
#        -0.0349431 ,  0.6428807 , -0.61927798,  0.90220628,  0.16416906])

# %%
import random

random.random()
# Out:
# 0.09836032552632501
