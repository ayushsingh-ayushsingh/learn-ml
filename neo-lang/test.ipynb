# %%
import json
from dotenv import load_dotenv

# %%
from langchain_neo4j import Neo4jVector

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_neo4j import Neo4jVector
from langchain_openai import OpenAIEmbeddings

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="nomic-embed-text-v2-moe")

# %%
loader = TextLoader("./bhagat_singh.txt")

documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=600,
    chunk_overlap=200
)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

db = Neo4jVector.from_documents(
    docs, embeddings, url=url, username=username, password=password
)

query = "What did the president say about Ketanji Brown Jackson"
docs_with_score = db.similarity_search_with_score(query, k=2)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[16], line 7
#       4 text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=0)
#       5 docs = text_splitter.split_documents(documents)
# ----> 7 embeddings = OpenAIEmbeddings()
#       9 # The Neo4jVector Module will connect to Neo4j and create a vector index if needed.
#      11 db = Neo4jVector.from_documents(
#      12     docs, embeddings, url=url, username=username, password=password
#      13 )
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/learn-ml/.venv/lib/python3.14/site-packages/langchain_openai/embeddings/base.py:406, in OpenAIEmbeddings.validate_environment(self)
#     401         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     402     async_specific = {
#     403         "http_client": self.http_async_client,
#     404         "api_key": async_api_key_value,
#     405     }
# --> 406     self.async_client = openai.AsyncOpenAI(
#     407         **client_params,
#     408         **async_specific,  # type: ignore[arg-type]
#     409     ).embeddings
#     410 return self
#
# File ~/Documents/learn-ml/.venv/lib/python3.14/site-packages/openai/_client.py:496, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     494     api_key = os.environ.get("OPENAI_API_KEY")
#     495 if api_key is None:
# --> 496     raise OpenAIError(
#     497         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     498     )
#     499 if callable(api_key):
#     500     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
